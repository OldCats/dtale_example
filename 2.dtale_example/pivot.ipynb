# %%
import pandas as pd

df = pd.read_csv('data_export_1647235277540.csv')

pd.pivot_table(df, index=['State','Exterior color'], values=['id'], aggfunc='count')
# Out:
#                       id
# State Exterior color
# AK    Null             4
#       black            5
#       blue             2
#       gray             6
#       light blue       6
# ...                   ..
# WY    light gray       4
#       light pink       4
#       pink             1
#       white           13
#       yelow           13
#
# [567 rows x 1 columns]

# %%
df.columns
# Out:
# Index(['Floors', 'waterfront', 'id', 'DateAdded', 'Price', 'Exterior color',
#        'Bedrooms', 'Bathrooms', 'View', 'Condition', 'Grade', 'Sqft_living',
#        'Sqft_lot', 'Sqft_above', 'Sqft_basement', 'Yr_built', 'Yr_renovated',
#        'timedelta', 'Country', 'Country-ISO', 'Full-State', 'State', 'City',
#        'County', 'lat', 'long', 'NeighborhoodName', 'ZipCode'],
#       dtype='object')
